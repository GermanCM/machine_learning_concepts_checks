# %%
import pandas as pd 
import numpy as np

n=1000
t=1.4
sigma_R = t*0.001
min_value_t = t-sigma_R
max_value_t = t+sigma_R
y_data = min_value_t + (max_value_t - min_value_t) * np.random.rand(n,1)
x_data=np.array(range(1000))

final_df_DICT = {'X': x_data}
H = pd.DataFrame(final_df_DICT)
feature_matrix = np.zeros(n*2) 
feature_matrix.shape = (n, 2) 
feature_matrix[:,0] = 1 
feature_matrix[:,1] = H['X'] 
feature_matrix
# Out:
# array([[  1.,   0.],
#        [  1.,   1.],
#        [  1.,   2.],
#        ...,
#        [  1., 997.],
#        [  1., 998.],
#        [  1., 999.]])

# %%
#standardize features
feature_matrix = (feature_matrix - feature_matrix.mean()) / feature_matrix.std()
target_data = y_data.reshape(len(y_data), )

# %%
w = [0, 0]
L=0.0001
epochs=5
iteration = 0
cost=[]
while iteration < epochs:
    pred = np.dot(feature_matrix, w)
    residuals = pred-target_data
    gradient_sum_squares = 0
    for i in range(len(w)):
        partial = 2*np.dot(residuals, feature_matrix[:, i])
        gradient_sum_squares += partial**2
        w[i] = w[i] - L*partial
    
    iteration += 1
    computed_cost = np.sum(np.power((pred - target_data), 2)) / n

    cost.append(computed_cost)

print('coef: {}'.format(w))
print('cost: {}'.format(cost[-1]))
# Out:
# coef: [-0.7040554399031753, 0.47254830931945235]
# cost: 0.49226558622687844

# %%
from matplotlib import pyplot

my_predictions = np.dot(feature_matrix, w)
pyplot.scatter(feature_matrix[:, 1], target_data)
pyplot.scatter(feature_matrix[:, 1], my_predictions, color='r')

pyplot.show()

# %%
from matplotlib import pyplot

my_predictions = np.dot(feature_matrix, w)
pyplot.scatter(feature_matrix[:, 1], target_data)
pyplot.scatter(feature_matrix[:, 1], my_predictions, color='r')

pyplot.show()

# %%
w = [0, 0]
L=0.0001
epochs=50
iteration = 0
cost=[]
while iteration < epochs:
    pred = np.dot(feature_matrix, w)
    residuals = pred-target_data
    gradient_sum_squares = 0
    for i in range(len(w)):
        partial = 2*np.dot(residuals, feature_matrix[:, i])
        gradient_sum_squares += partial**2
        w[i] = w[i] - L*partial
    
    iteration += 1
    computed_cost = np.sum(np.power((pred - target_data), 2)) / n

    cost.append(computed_cost)

print('coef: {}'.format(w))
print('cost: {}'.format(cost[-1]))
# Out:
# coef: [-1.7300111097332245, 0.042435916822675605]
# cost: 0.002548366980972693

# %%
from matplotlib import pyplot

my_predictions = np.dot(feature_matrix, w)
pyplot.scatter(feature_matrix[:, 1], target_data)
pyplot.scatter(feature_matrix[:, 1], my_predictions, color='r')

pyplot.show()

# %%
w = [0, 0]
L=0.0001
epochs=80
iteration = 0
cost=[]
while iteration < epochs:
    pred = np.dot(feature_matrix, w)
    residuals = pred-target_data
    gradient_sum_squares = 0
    for i in range(len(w)):
        partial = 2*np.dot(residuals, feature_matrix[:, i])
        gradient_sum_squares += partial**2
        w[i] = w[i] - L*partial
    
    iteration += 1
    computed_cost = np.sum(np.power((pred - target_data), 2)) / n

    cost.append(computed_cost)

print('coef: {}'.format(w))
print('cost: {}'.format(cost[-1]))
# Out:
# coef: [-1.7953896901150361, 0.007563018660700881]
# cost: 8.164793971702578e-05

# %%
from matplotlib import pyplot

my_predictions = np.dot(feature_matrix, w)
pyplot.scatter(feature_matrix[:, 1], target_data)
pyplot.scatter(feature_matrix[:, 1], my_predictions, color='r')

pyplot.show()

# %%
w = [0, 0]
L=0.0001
epochs=100
iteration = 0
cost=[]
while iteration < epochs:
    pred = np.dot(feature_matrix, w)
    residuals = pred-target_data
    gradient_sum_squares = 0
    for i in range(len(w)):
        partial = 2*np.dot(residuals, feature_matrix[:, i])
        gradient_sum_squares += partial**2
        w[i] = w[i] - L*partial
    
    iteration += 1
    computed_cost = np.sum(np.power((pred - target_data), 2)) / n

    cost.append(computed_cost)

print('coef: {}'.format(w))
print('cost: {}'.format(cost[-1]))
# Out:
# coef: [-1.8050815668899338, 0.002393376917573127]
# cost: 8.78963940638772e-06

# %%
from matplotlib import pyplot

my_predictions = np.dot(feature_matrix, w)
pyplot.scatter(feature_matrix[:, 1], target_data)
pyplot.scatter(feature_matrix[:, 1], my_predictions, color='r')

pyplot.show()

# %%
w = [0, 0]
L=0.0001
epochs=1000
iteration = 0
cost=[]
while iteration < epochs:
    pred = np.dot(feature_matrix, w)
    residuals = pred-target_data
    gradient_sum_squares = 0
    for i in range(len(w)):
        partial = 2*np.dot(residuals, feature_matrix[:, i])
        gradient_sum_squares += partial**2
        w[i] = w[i] - L*partial
    
    iteration += 1
    computed_cost = np.sum(np.power((pred - target_data), 2)) / n

    cost.append(computed_cost)

print('coef: {}'.format(w))
print('cost: {}'.format(cost[-1]))
# Out:
# coef: [-1.8095751845799084, -3.5162876654368155e-06]
# cost: 6.630716050715097e-07

# %%
from matplotlib import pyplot

my_predictions = np.dot(feature_matrix, w)
pyplot.scatter(feature_matrix[:, 1], target_data)
pyplot.scatter(feature_matrix[:, 1], my_predictions, color='r')

pyplot.show()
